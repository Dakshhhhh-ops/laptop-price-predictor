# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('laptop_data.csv')

# %%
df.head()
# Out:
#    Unnamed: 0 Company   TypeName  Inches                    ScreenResolution  \
# 0           0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1           1   Apple  Ultrabook    13.3                            1440x900
# 2           2      HP   Notebook    15.6                   Full HD 1920x1080
# 3           3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4           4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# ...

# %%
df.shape
# Out:
# (1303, 12)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        1303 non-null   int64
#  1   Company           1303 non-null   str
#  2   TypeName          1303 non-null   str
#  3   Inches            1303 non-null   float64
#  4   ScreenResolution  1303 non-null   str
#  5   Cpu               1303 non-null   str
#  6   Ram               1303 non-null   str
#  7   Memory            1303 non-null   str
#  8   Gpu               1303 non-null   str
#  9   OpSys             1303 non-null   str
#  10  Weight            1303 non-null   str
#  11  Price             1303 non-null   float64
# dtypes: float64(2), int64(1), str(9)
# memory usage: 122.3 KB

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Company', 'TypeName', 'Inches', 'ScreenResolution',
#        'Cpu', 'Ram', 'Memory', 'Gpu', 'OpSys', 'Weight', 'Price'],
#       dtype='str')

# %%
df.isnull().sum()
# Out:
# Unnamed: 0          0
# Company             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price               0
# dtype: int64

# %%
df.drop(columns=['Unnamed: 0'],inplace=True)

# %%
df.head()
# Out:
#    Unnamed: 0 Company   TypeName  Inches                    ScreenResolution  \
# 0           0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1           1   Apple  Ultrabook    13.3                            1440x900
# 2           2      HP   Notebook    15.6                   Full HD 1920x1080
# 3           3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4           4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# ...

# %%
# removing gb from ram and converting to int
df['Ram']=df['Ram'].str.replace('GB','')

# %%
df.head()
# Out:
#    Unnamed: 0 Company   TypeName  Inches                    ScreenResolution  \
# 0           0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1           1   Apple  Ultrabook    13.3                            1440x900
# 2           2      HP   Notebook    15.6                   Full HD 1920x1080
# 3           3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4           4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8            128GB SSD
# 1        Intel Core i5 1.8GHz   8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8            256GB SSD
# 3        Intel Core i7 2.7GHz  16            512GB SSD
# 4        Intel Core i5 3.1GHz   8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# ...

# %%
df['Ram']=df['Ram'].astype('int32')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        1303 non-null   int64
#  1   Company           1303 non-null   str
#  2   TypeName          1303 non-null   str
#  3   Inches            1303 non-null   float64
#  4   ScreenResolution  1303 non-null   str
#  5   Cpu               1303 non-null   str
#  6   Ram               1303 non-null   int32
#  7   Memory            1303 non-null   str
#  8   Gpu               1303 non-null   str
#  9   OpSys             1303 non-null   str
#  10  Weight            1303 non-null   str
#  11  Price             1303 non-null   float64
# dtypes: float64(2), int32(1), int64(1), str(8)
# memory usage: 117.2 KB

# %%
#removing kg from weights and converting to string
df['Weight']=df['Weight'].str.replace('kg','')

# %%
df['Weight']=df['Weight'].astype('float32')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        1303 non-null   int64
#  1   Company           1303 non-null   str
#  2   TypeName          1303 non-null   str
#  3   Inches            1303 non-null   float64
#  4   ScreenResolution  1303 non-null   str
#  5   Cpu               1303 non-null   str
#  6   Ram               1303 non-null   int32
#  7   Memory            1303 non-null   str
#  8   Gpu               1303 non-null   str
#  9   OpSys             1303 non-null   str
#  10  Weight            1303 non-null   float32
#  11  Price             1303 non-null   float64
# dtypes: float32(1), float64(2), int32(1), int64(1), str(7)
# memory usage: 112.1 KB

# %%
df['Company'].value_counts()
# Out:
# Company
# Dell         297
# Lenovo       297
# HP           274
# Asus         158
# Acer         103
# MSI           54
# Toshiba       48
# Apple         21
# Samsung        9
# Razer          7
# Mediacom       7
# Microsoft      6
# Xiaomi         4
# Vero           4
# Chuwi          3
# Google         3
# Fujitsu        3
# LG             3
# Huawei         2
# Name: count, dtype: int64

# %%
import seaborn as sns
sns.displot(df['Price'])

# %% [markdown]
# Right skewed

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(14,6))
sns.barplot(x=df['Company'],y=df['Price'])
plt.show()

# %%
df['TypeName'].value_counts()
# Out:
# TypeName
# Notebook              727
# Gaming                205
# Ultrabook             196
# 2 in 1 Convertible    121
# Workstation            29
# Netbook                25
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(14,6))
sns.barplot(x=df['TypeName'],y=df['Price'])
plt.show()

# %%
sns.displot(df['Inches'])

# %%
df['ScreenResolution'].value_counts()
# Out:
# ScreenResolution
# Full HD 1920x1080                                507
# 1366x768                                         281
# IPS Panel Full HD 1920x1080                      230
# IPS Panel Full HD / Touchscreen 1920x1080         53
# Full HD / Touchscreen 1920x1080                   47
# 1600x900                                          23
# Touchscreen 1366x768                              16
# Quad HD+ / Touchscreen 3200x1800                  15
# IPS Panel 4K Ultra HD 3840x2160                   12
# IPS Panel 4K Ultra HD / Touchscreen 3840x2160     11
# 4K Ultra HD / Touchscreen 3840x2160               10
# IPS Panel 1366x768                                 7
# Touchscreen 2560x1440                              7
# 4K Ultra HD 3840x2160                              7
# IPS Panel Retina Display 2560x1600                 6
# IPS Panel Retina Display 2304x1440                 6
# Touchscreen 2256x1504                              6
# ...

# %%
#making new column whether a laptop is touchscreen or not
def is_touchscreen(x):
    if 'Touchscreen' in x:
        return 1
    else:
        return 0

# %%
df['Touchscreen']=df['ScreenResolution'].apply(is_touchscreen)

# %%
df.head(
    
)
# Out:
#    Unnamed: 0 Company   TypeName  Inches                    ScreenResolution  \
# 0           0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1           1   Apple  Ultrabook    13.3                            1440x900
# 2           2      HP   Notebook    15.6                   Full HD 1920x1080
# 3           3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4           4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0
# ...

# %%
df['Touchscreen'].value_counts()
# Out:
# Touchscreen
# 0    1111
# 1     192
# Name: count, dtype: int64

# %%
sns.barplot(x=df['Touchscreen'],y=df['Price'])
# Out:
# <Axes: xlabel='Touchscreen', ylabel='Price'>

# %%
def has_ips(x):
    if 'IPS' in x:
        return 1
    else:
        return 0

# %%
df['IPS']=df['ScreenResolution'].apply(has_ips)

# %%
df.head()
# Out:
#    Unnamed: 0 Company   TypeName  Inches                    ScreenResolution  \
# 0           0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1           1   Apple  Ultrabook    13.3                            1440x900
# 2           2      HP   Notebook    15.6                   Full HD 1920x1080
# 3           3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4           4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  IPS
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# ...

# %%
df['IPS'].value_counts()
# Out:
# IPS
# 0    938
# 1    365
# Name: count, dtype: int64

# %%
sns.barplot(x=df['IPS'],y=df['Price'])
# Out:
# <Axes: xlabel='IPS', ylabel='Price'>

# %%
df['Resolution'] = df['ScreenResolution'].str.extract(r'(\d+x\d+)')

# %%
df['X_res'] = df['Resolution'].str.split('x').str[0].astype(int)
df['Y_res'] = df['Resolution'].str.split('x').str[1].astype(int)

# %%
df.head()
# Out:
#    Unnamed: 0 Company   TypeName  Inches                    ScreenResolution  \
# 0           0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1           1   Apple  Ultrabook    13.3                            1440x900
# 2           2      HP   Notebook    15.6                   Full HD 1920x1080
# 3           3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4           4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  IPS  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# ...

# %%
df.select_dtypes(include='number').corr()['Price']
# Out:
# Unnamed: 0     0.067984
# Inches         0.068197
# Ram            0.743007
# Weight         0.210370
# Price          1.000000
# Touchscreen    0.191226
# IPS            0.252208
# X_res          0.556529
# Y_res          0.552809
# Name: Price, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        1303 non-null   int64
#  1   Company           1303 non-null   str
#  2   TypeName          1303 non-null   str
#  3   Inches            1303 non-null   float64
#  4   ScreenResolution  1303 non-null   str
#  5   Cpu               1303 non-null   str
#  6   Ram               1303 non-null   int32
#  7   Memory            1303 non-null   str
#  8   Gpu               1303 non-null   str
#  9   OpSys             1303 non-null   str
#  10  Weight            1303 non-null   float32
#  11  Price             1303 non-null   float64
#  12  Touchscreen       1303 non-null   int64
#  13  IPS               1303 non-null   int64
#  14  Resolution        1303 non-null   str
#  15  X_res             1303 non-null   int64
#  16  Y_res             1303 non-null   int64
# ...

# %%
import numpy as np

df['PPI'] = (
    ((df['X_res']**2 + df['Y_res']**2)**0.5)
    / df['Inches']
).astype('float')

# %%
df.select_dtypes(include='number').corr()['Price']
# Out:
# Unnamed: 0     0.067984
# Inches         0.068197
# Ram            0.743007
# Weight         0.210370
# Price          1.000000
# Touchscreen    0.191226
# IPS            0.252208
# X_res          0.556529
# Y_res          0.552809
# PPI            0.473487
# Name: Price, dtype: float64

# %%
#now dropping screen resolution
df.drop(columns=['ScreenResolution'],inplace=True)

# %%
df.head()
# Out:
#    Unnamed: 0 Company   TypeName  Inches                         Cpu  Ram  \
# 0           0   Apple  Ultrabook    13.3        Intel Core i5 2.3GHz    8
# 1           1   Apple  Ultrabook    13.3        Intel Core i5 1.8GHz    8
# 2           2      HP   Notebook    15.6  Intel Core i5 7200U 2.5GHz    8
# 3           3   Apple  Ultrabook    15.4        Intel Core i7 2.7GHz   16
# 4           4   Apple  Ultrabook    13.3        Intel Core i5 3.1GHz    8
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS    1.37
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS    1.34
# 2            256GB SSD         Intel HD Graphics 620  No OS    1.86
# 3            512GB SSD            AMD Radeon Pro 455  macOS    1.83
# 4            256GB SSD  Intel Iris Plus Graphics 650  macOS    1.37
#
#          Price  Touchscreen  IPS Resolution  X_res  Y_res         PPI
# ...

# %%
df.drop(columns=['X_res', 'Y_res'], inplace=True)

# %%
df.head()
# Out:
#    Unnamed: 0 Company   TypeName  Inches                         Cpu  Ram  \
# 0           0   Apple  Ultrabook    13.3        Intel Core i5 2.3GHz    8
# 1           1   Apple  Ultrabook    13.3        Intel Core i5 1.8GHz    8
# 2           2      HP   Notebook    15.6  Intel Core i5 7200U 2.5GHz    8
# 3           3   Apple  Ultrabook    15.4        Intel Core i7 2.7GHz   16
# 4           4   Apple  Ultrabook    13.3        Intel Core i5 3.1GHz    8
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS    1.37
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS    1.34
# 2            256GB SSD         Intel HD Graphics 620  No OS    1.86
# 3            512GB SSD            AMD Radeon Pro 455  macOS    1.83
# 4            256GB SSD  Intel Iris Plus Graphics 650  macOS    1.37
#
#          Price  Touchscreen  IPS Resolution         PPI
# ...

# %%
df.drop(columns=['Resolution'], inplace=True)

# %%
df.head()
# Out:
#    Unnamed: 0 Company   TypeName  Inches                         Cpu  Ram  \
# 0           0   Apple  Ultrabook    13.3        Intel Core i5 2.3GHz    8
# 1           1   Apple  Ultrabook    13.3        Intel Core i5 1.8GHz    8
# 2           2      HP   Notebook    15.6  Intel Core i5 7200U 2.5GHz    8
# 3           3   Apple  Ultrabook    15.4        Intel Core i7 2.7GHz   16
# 4           4   Apple  Ultrabook    13.3        Intel Core i5 3.1GHz    8
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS    1.37
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS    1.34
# 2            256GB SSD         Intel HD Graphics 620  No OS    1.86
# 3            512GB SSD            AMD Radeon Pro 455  macOS    1.83
# 4            256GB SSD  Intel Iris Plus Graphics 650  macOS    1.37
#
#          Price  Touchscreen  IPS         PPI
# 0   71378.6832            0    1  226.983005
# ...

# %%
df['Cpu'].value_counts()
# Out:
# Cpu
# Intel Core i5 7200U 2.5GHz              190
# Intel Core i7 7700HQ 2.8GHz             146
# Intel Core i7 7500U 2.7GHz              134
# Intel Core i7 8550U 1.8GHz               73
# Intel Core i5 8250U 1.6GHz               72
#                                        ...
# Intel Core i5 7200U 2.7GHz                1
# Intel Pentium Dual Core 4405Y 1.5GHz      1
# Intel Core M 6Y54 1.1GHz                  1
# Samsung Cortex A72&A53 2.0GHz             1
# AMD E-Series 9000 2.2GHz                  1
# Name: count, Length: 118, dtype: int64

# %%
df['Cpu Name'] = df['Cpu'].apply(lambda x: " ".join(x.split()[0:3]))

# %%
df.head()
# Out:
#    Unnamed: 0 Company   TypeName  Inches                         Cpu  Ram  \
# 0           0   Apple  Ultrabook    13.3        Intel Core i5 2.3GHz    8
# 1           1   Apple  Ultrabook    13.3        Intel Core i5 1.8GHz    8
# 2           2      HP   Notebook    15.6  Intel Core i5 7200U 2.5GHz    8
# 3           3   Apple  Ultrabook    15.4        Intel Core i7 2.7GHz   16
# 4           4   Apple  Ultrabook    13.3        Intel Core i5 3.1GHz    8
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS    1.37
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS    1.34
# 2            256GB SSD         Intel HD Graphics 620  No OS    1.86
# 3            512GB SSD            AMD Radeon Pro 455  macOS    1.83
# 4            256GB SSD  Intel Iris Plus Graphics 650  macOS    1.37
#
#          Price  Touchscreen  IPS         PPI       Cpu Name
# ...

# %%
df['Cpu Name'].value_counts()
# Out:
# Cpu Name
# Intel Core i7               527
# Intel Core i5               423
# Intel Core i3               136
# Intel Celeron Dual           80
# Intel Pentium Quad           27
# Intel Core M                 19
# AMD A9-Series 9420           12
# AMD A6-Series 9220            8
# Intel Celeron Quad            8
# AMD A12-Series 9720P          7
# Intel Atom x5-Z8350           5
# Intel Atom x5-Z8550           4
# AMD A8-Series 7410            4
# AMD Ryzen 1700                3
# Intel Pentium Dual            3
# AMD A9-Series 9410            3
# AMD E-Series E2-9000e         2
# Intel Xeon E3-1505M           2
# AMD A10-Series A10-9620P      2
# AMD A6-Series A6-9220         2
# AMD A10-Series 9600P          2
# AMD A10-Series 9620P          2
# AMD E-Series 7110             2
# AMD A9-Series A9-9420         2
# Intel Xeon E3-1535M           2
# Intel Atom X5-Z8350           2
# Intel Atom x5-Z8300           1
# AMD E-Series E2-6110          1
# AMD FX 9830P                  1
# ...

# %%
def fetch_processor(text):
    if text == 'Intel Core i7':
        return 'Intel Core i7'
    elif text == 'Intel Core i5':
        return 'Intel Core i5'
    elif text == 'Intel Core i3':
        return 'Intel Core i3'
    elif text.startswith('AMD'):
        return 'AMD Processor'
    else:
        return 'Other Intel Processor'

df['Cpu Brand'] = df['Cpu Name'].apply(fetch_processor)

# %%
df.head()
# Out:
#    Unnamed: 0 Company   TypeName  Inches                         Cpu  Ram  \
# 0           0   Apple  Ultrabook    13.3        Intel Core i5 2.3GHz    8
# 1           1   Apple  Ultrabook    13.3        Intel Core i5 1.8GHz    8
# 2           2      HP   Notebook    15.6  Intel Core i5 7200U 2.5GHz    8
# 3           3   Apple  Ultrabook    15.4        Intel Core i7 2.7GHz   16
# 4           4   Apple  Ultrabook    13.3        Intel Core i5 3.1GHz    8
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS    1.37
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS    1.34
# 2            256GB SSD         Intel HD Graphics 620  No OS    1.86
# 3            512GB SSD            AMD Radeon Pro 455  macOS    1.83
# 4            256GB SSD  Intel Iris Plus Graphics 650  macOS    1.37
#
#          Price  Touchscreen  IPS         PPI       Cpu Name      Cpu Brand
# ...

# %%
df['Cpu Brand'].value_counts()
# Out:
# Cpu Brand
# Intel Core i7            527
# Intel Core i5            423
# Other Intel Processor    155
# Intel Core i3            136
# AMD Processor             62
# Name: count, dtype: int64

# %%
sns.barplot(x=df['Cpu Brand'],y=df['Price'])
# Out:
# <Axes: xlabel='Cpu Brand', ylabel='Price'>

# %%
df['Cpu Speed'] = df['Cpu'].str.extract(r'(\d+\.?\d*)GHz')
df['Cpu Speed'] = df['Cpu Speed'].astype(float)

# %%
df.head()
# Out:
#    Unnamed: 0 Company   TypeName  Inches                         Cpu  Ram  \
# 0           0   Apple  Ultrabook    13.3        Intel Core i5 2.3GHz    8
# 1           1   Apple  Ultrabook    13.3        Intel Core i5 1.8GHz    8
# 2           2      HP   Notebook    15.6  Intel Core i5 7200U 2.5GHz    8
# 3           3   Apple  Ultrabook    15.4        Intel Core i7 2.7GHz   16
# 4           4   Apple  Ultrabook    13.3        Intel Core i5 3.1GHz    8
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS    1.37
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS    1.34
# 2            256GB SSD         Intel HD Graphics 620  No OS    1.86
# 3            512GB SSD            AMD Radeon Pro 455  macOS    1.83
# 4            256GB SSD  Intel Iris Plus Graphics 650  macOS    1.37
#
#          Price  Touchscreen  IPS         PPI       Cpu Name      Cpu Brand  \
# ...

# %%
df[['Cpu Speed', 'Price']].corr()
# Out:
#            Cpu Speed     Price
# Cpu Speed   1.000000  0.430293
# Price       0.430293  1.000000

# %%
df.select_dtypes(include='number').corr()['Price'].sort_values(ascending=False)
# Out:
# Price          1.000000
# Ram            0.743007
# PPI            0.473487
# Cpu Speed      0.430293
# IPS            0.252208
# Weight         0.210370
# Touchscreen    0.191226
# Inches         0.068197
# Unnamed: 0     0.067984
# Name: Price, dtype: float64

# %%
df.drop(columns=['Cpu'], inplace=True)

# %%
df.head()
# Out:
#    Unnamed: 0 Company   TypeName  Inches  Ram               Memory  \
# 0           0   Apple  Ultrabook    13.3    8            128GB SSD
# 1           1   Apple  Ultrabook    13.3    8  128GB Flash Storage
# 2           2      HP   Notebook    15.6    8            256GB SSD
# 3           3   Apple  Ultrabook    15.4   16            512GB SSD
# 4           4   Apple  Ultrabook    13.3    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  IPS  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0    1
#
#           PPI       Cpu Name      Cpu Brand  Cpu Speed
# ...

# %%
df.drop(columns=['Cpu Name'], inplace=True)

# %%
df.head()
# Out:
#    Unnamed: 0 Company   TypeName  Inches  Ram               Memory  \
# 0           0   Apple  Ultrabook    13.3    8            128GB SSD
# 1           1   Apple  Ultrabook    13.3    8  128GB Flash Storage
# 2           2      HP   Notebook    15.6    8            256GB SSD
# 3           3   Apple  Ultrabook    15.4   16            512GB SSD
# 4           4   Apple  Ultrabook    13.3    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  IPS  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0    1
#
#           PPI      Cpu Brand  Cpu Speed
# 0  226.983005  Intel Core i5        2.3
# ...

# %%
df['Ram'].value_counts()
# Out:
# Ram
# 8     619
# 4     375
# 16    200
# 6      41
# 12     25
# 2      22
# 32     17
# 24      3
# 64      1
# Name: count, dtype: int64

# %%
df['Memory'].value_counts()
# Out:
# Memory
# 256GB SSD                        412
# 1TB HDD                          223
# 500GB HDD                        132
# 512GB SSD                        118
# 128GB SSD +  1TB HDD              94
# 128GB SSD                         76
# 256GB SSD +  1TB HDD              73
# 32GB Flash Storage                38
# 2TB HDD                           16
# 64GB Flash Storage                15
# 512GB SSD +  1TB HDD              14
# 1TB SSD                           14
# 256GB SSD +  2TB HDD              10
# 1.0TB Hybrid                       9
# 256GB Flash Storage                8
# 16GB Flash Storage                 7
# 32GB SSD                           6
# 180GB SSD                          5
# 128GB Flash Storage                4
# 16GB SSD                           3
# 512GB SSD +  2TB HDD               3
# 256GB SSD +  256GB SSD             2
# 256GB SSD +  500GB HDD             2
# 128GB SSD +  2TB HDD               2
# 1TB SSD +  1TB HDD                 2
# ...

# %%
df['Memory'] = df['Memory'].str.replace('.0', '', regex=False)
df['Memory'] = df['Memory'].str.replace('TB', '000')
df['Memory'] = df['Memory'].str.replace('GB', '')

new = df["Memory"].str.split("+", n=1, expand=True)

df["first"] = new[0]
df["second"] = new[1]

df["second"] = df["second"].fillna("0")

df["HDD"] = 0
df["SSD"] = 0
df["Hybrid"] = 0
df["Flash_Storage"] = 0

for i in df.index:
    for part in [df.loc[i, 'first'], df.loc[i, 'second']]:
        if 'HDD' in part:
            df.loc[i, 'HDD'] += int(''.join(filter(str.isdigit, part)))
        elif 'SSD' in part:
            df.loc[i, 'SSD'] += int(''.join(filter(str.isdigit, part)))
        elif 'Hybrid' in part:
            df.loc[i, 'Hybrid'] += int(''.join(filter(str.isdigit, part)))
        elif 'Flash Storage' in part:
            df.loc[i, 'Flash_Storage'] += int(''.join(filter(str.isdigit, part)))

# %%
df.head()
# Out:
#    Unnamed: 0 Company   TypeName  Inches  Ram             Memory  \
# 0           0   Apple  Ultrabook    13.3    8            128 SSD
# 1           1   Apple  Ultrabook    13.3    8  128 Flash Storage
# 2           2      HP   Notebook    15.6    8            256 SSD
# 3           3   Apple  Ultrabook    15.4   16            512 SSD
# 4           4   Apple  Ultrabook    13.3    8            256 SSD
#
#                             Gpu  OpSys  Weight        Price  ...  IPS  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832  ...    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232  ...    0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000  ...    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360  ...    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080  ...    1
#
#           PPI      Cpu Brand Cpu Speed              first second HDD  SSD  \
# 0  226.983005  Intel Core i5       2.3            128 SSD      0   0  128
# ...

# %%
df.drop(['Memory', 'first', 'second'], axis=1, inplace=True)

# %%
df[['HDD','SSD','Hybrid','Flash_Storage','Price']].corr()
# Out:
#                     HDD       SSD    Hybrid  Flash_Storage     Price
# HDD            1.000000 -0.399896 -0.076596      -0.117658 -0.096441
# SSD           -0.399896  1.000000 -0.059750      -0.147991  0.670799
# Hybrid        -0.076596 -0.059750  1.000000      -0.014368  0.007989
# Flash_Storage -0.117658 -0.147991 -0.014368       1.000000 -0.040511
# Price         -0.096441  0.670799  0.007989      -0.040511  1.000000

# %%
(df['Hybrid'] > 0).sum()
# Out:
# np.int64(12)

# %%
(df['Flash_Storage'] > 0).sum()
# Out:
# np.int64(75)

# %%
df.drop(columns=['Flash_Storage'], inplace=True)

# %%
df.drop(columns=['Hybrid'], inplace=True)

# %%
(df['HDD'] > 0).sum()
# Out:
# np.int64(576)

# %%
df['Gpu'].value_counts()
# Out:
# Gpu
# Intel HD Graphics 620      281
# Intel HD Graphics 520      185
# Intel UHD Graphics 620      68
# Nvidia GeForce GTX 1050     66
# Nvidia GeForce GTX 1060     48
#                           ...
# Nvidia Quadro M500M          1
# AMD Radeon R7 M360           1
# Nvidia Quadro M3000M         1
# Nvidia GeForce 960M          1
# ARM Mali T860 MP4            1
# Name: count, Length: 110, dtype: int64

# %%
df['Gpu_brand']=df['Gpu'].apply(lambda x:x.split()[0])

# %%
df.head()
# Out:
#   Company   TypeName  Inches  Ram    Gpu  OpSys  Weight        Price  \
# 0   Apple  Ultrabook    13.3    8  Intel  macOS    1.37   71378.6832
# 1   Apple  Ultrabook    13.3    8  Intel  macOS    1.34   47895.5232
# 2      HP   Notebook    15.6    8  Intel  No OS    1.86   30636.0000
# 3   Apple  Ultrabook    15.4   16    AMD  macOS    1.83  135195.3360
# 4   Apple  Ultrabook    13.3    8  Intel  macOS    1.37   96095.8080
#
#    Touchscreen  IPS         PPI      Cpu Brand  Cpu Speed  HDD  SSD Gpu_brand
# 0            0    1  226.983005  Intel Core i5        2.3    0  128     Intel
# 1            0    0  127.677940  Intel Core i5        1.8    0    0     Intel
# 2            0    0  141.211998  Intel Core i5        2.5    0  256     Intel
# 3            0    1  220.534624  Intel Core i7        2.7    0  512       AMD
# 4            0    1  226.983005  Intel Core i5        3.1    0  256     Intel

# %%
df=df[df['Gpu_brand']!='ARM']

# %%
df['Gpu_brand'].value_counts()
# Out:
# Gpu_brand
# Intel     722
# Nvidia    400
# AMD       180
# Name: count, dtype: int64

# %%
df.drop(columns=['Gpu'],inplace=True)

# %%
df.head(
    
)
# Out:
#   Company   TypeName  Inches  Ram  OpSys  Weight        Price  Touchscreen  \
# 0   Apple  Ultrabook    13.3    8  macOS    1.37   71378.6832            0
# 1   Apple  Ultrabook    13.3    8  macOS    1.34   47895.5232            0
# 2      HP   Notebook    15.6    8  No OS    1.86   30636.0000            0
# 3   Apple  Ultrabook    15.4   16  macOS    1.83  135195.3360            0
# 4   Apple  Ultrabook    13.3    8  macOS    1.37   96095.8080            0
#
#    IPS         PPI      Cpu Brand  Cpu Speed  HDD  SSD Gpu_brand
# 0    1  226.983005  Intel Core i5        2.3    0  128     Intel
# 1    0  127.677940  Intel Core i5        1.8    0    0     Intel
# 2    0  141.211998  Intel Core i5        2.5    0  256     Intel
# 3    1  220.534624  Intel Core i7        2.7    0  512       AMD
# 4    1  226.983005  Intel Core i5        3.1    0  256     Intel

# %%
df.drop(columns=['Inches'],inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  Ram  OpSys  Weight        Price  Touchscreen  IPS  \
# 0   Apple  Ultrabook    8  macOS    1.37   71378.6832            0    1
# 1   Apple  Ultrabook    8  macOS    1.34   47895.5232            0    0
# 2      HP   Notebook    8  No OS    1.86   30636.0000            0    0
# 3   Apple  Ultrabook   16  macOS    1.83  135195.3360            0    1
# 4   Apple  Ultrabook    8  macOS    1.37   96095.8080            0    1
#
#           PPI      Cpu Brand  Cpu Speed  HDD  SSD Gpu_brand
# 0  226.983005  Intel Core i5        2.3    0  128     Intel
# 1  127.677940  Intel Core i5        1.8    0    0     Intel
# 2  141.211998  Intel Core i5        2.5    0  256     Intel
# 3  220.534624  Intel Core i7        2.7    0  512       AMD
# 4  226.983005  Intel Core i5        3.1    0  256     Intel

# %%
df['OpSys'].value_counts()
# Out:
# OpSys
# Windows 10      1072
# No OS             66
# Linux             62
# Windows 7         45
# Chrome OS         26
# macOS             13
# Mac OS X           8
# Windows 10 S       8
# Android            2
# Name: count, dtype: int64

# %%
def cat_os(inp):
    if inp=='Windows 10' or inp == 'Windows 7' or inp == 'Windows 10 S':
        return 'Windows'
    elif inp=='macOS' or inp=='Mac OS X':
        return 'Mac'
    else:
        return 'Others/No OS/Linux'

# %%
df['os']=df['OpSys'].apply(cat_os)

# %%
df.head()
# Out:
#   Company   TypeName  Ram  OpSys  Weight        Price  Touchscreen  IPS  \
# 0   Apple  Ultrabook    8  macOS    1.37   71378.6832            0    1
# 1   Apple  Ultrabook    8  macOS    1.34   47895.5232            0    0
# 2      HP   Notebook    8  No OS    1.86   30636.0000            0    0
# 3   Apple  Ultrabook   16  macOS    1.83  135195.3360            0    1
# 4   Apple  Ultrabook    8  macOS    1.37   96095.8080            0    1
#
#           PPI      Cpu Brand  Cpu Speed  HDD  SSD Gpu_brand  \
# 0  226.983005  Intel Core i5        2.3    0  128     Intel
# 1  127.677940  Intel Core i5        1.8    0    0     Intel
# 2  141.211998  Intel Core i5        2.5    0  256     Intel
# 3  220.534624  Intel Core i7        2.7    0  512       AMD
# 4  226.983005  Intel Core i5        3.1    0  256     Intel
#
#                    os
# 0                 Mac
# 1                 Mac
# 2  Others/No OS/Linux
# 3                 Mac
# 4                 Mac

# %%
df.drop(columns=['OpSys'],inplace=True)

# %%
df.head(
    
)
# Out:
#   Company   TypeName  Ram  Weight        Price  Touchscreen  IPS         PPI  \
# 0   Apple  Ultrabook    8    1.37   71378.6832            0    1  226.983005
# 1   Apple  Ultrabook    8    1.34   47895.5232            0    0  127.677940
# 2      HP   Notebook    8    1.86   30636.0000            0    0  141.211998
# 3   Apple  Ultrabook   16    1.83  135195.3360            0    1  220.534624
# 4   Apple  Ultrabook    8    1.37   96095.8080            0    1  226.983005
#
#        Cpu Brand  Cpu Speed  HDD  SSD Gpu_brand                  os
# 0  Intel Core i5        2.3    0  128     Intel                 Mac
# 1  Intel Core i5        1.8    0    0     Intel                 Mac
# 2  Intel Core i5        2.5    0  256     Intel  Others/No OS/Linux
# 3  Intel Core i7        2.7    0  512       AMD                 Mac
# 4  Intel Core i5        3.1    0  256     Intel                 Mac

# %%
sns.barplot(x=df['os'], y=df['Price'])
# Out:
# <Axes: xlabel='os', ylabel='Price'>

# %%
# making target column(price) normal by applyinh transformations
#log transformation
sns.distplot(np.log(df['Price']))
# Out:
# C:\Users\daksh\AppData\Local\Temp\ipykernel_26176\71507412.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(np.log(df['Price']))
# <Axes: xlabel='Price', ylabel='Density'>

# %%
X=df.drop(columns=['Price'])
y=np.log(df['Price'])

# %%
X
# Out:
#      Company            TypeName  Ram  Weight  Touchscreen  IPS         PPI  \
# 0      Apple           Ultrabook    8    1.37            0    1  226.983005
# 1      Apple           Ultrabook    8    1.34            0    0  127.677940
# 2         HP            Notebook    8    1.86            0    0  141.211998
# 3      Apple           Ultrabook   16    1.83            0    1  220.534624
# 4      Apple           Ultrabook    8    1.37            0    1  226.983005
# ...      ...                 ...  ...     ...          ...  ...         ...
# 1298  Lenovo  2 in 1 Convertible    4    1.80            1    1  157.350512
# 1299  Lenovo  2 in 1 Convertible   16    1.30            1    1  276.053530
# 1300  Lenovo            Notebook    2    1.50            0    0  111.935204
# 1301      HP            Notebook    6    2.19            0    0  100.454670
# 1302    Asus            Notebook    4    2.20            0    0  100.454670
#
# ...

# %%
y
# Out:
# 0       11.175755
# 1       10.776777
# 2       10.329931
# 3       11.814476
# 4       11.473101
#           ...
# 1298    10.433899
# 1299    11.288115
# 1300     9.409283
# 1301    10.614129
# 1302     9.886358
# Name: Price, Length: 1302, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.15,random_state=2)

# %%
## applying encoding
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import r2_score,mean_absolute_error

# %%
from sklearn.linear_model import LinearRegression,Ridge,Lasso
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor,GradientBoostingRegressor,AdaBoostRegressor,ExtraTreesRegressor
from sklearn.svm import SVR
from xgboost import XGBRegressor

# %%
df.head()
# Out:
#   Company   TypeName  Ram  Weight        Price  Touchscreen  IPS         PPI  \
# 0   Apple  Ultrabook    8    1.37   71378.6832            0    1  226.983005
# 1   Apple  Ultrabook    8    1.34   47895.5232            0    0  127.677940
# 2      HP   Notebook    8    1.86   30636.0000            0    0  141.211998
# 3   Apple  Ultrabook   16    1.83  135195.3360            0    1  220.534624
# 4   Apple  Ultrabook    8    1.37   96095.8080            0    1  226.983005
#
#        Cpu Brand  Cpu Speed  HDD  SSD Gpu_brand                  os
# 0  Intel Core i5        2.3    0  128     Intel                 Mac
# 1  Intel Core i5        1.8    0    0     Intel                 Mac
# 2  Intel Core i5        2.5    0  256     Intel  Others/No OS/Linux
# 3  Intel Core i7        2.7    0  512       AMD                 Mac
# 4  Intel Core i5        3.1    0  256     Intel                 Mac

# %%
step1 = ColumnTransformer(
    transformers=[
        ('col_tnf', OneHotEncoder(drop='first', sparse_output=False),
         [0,1,7,11,12])
    ],
    remainder='passthrough'
)

step2 = LinearRegression()

pipe = Pipeline([
    ('step1', step1),
    ('step2', step2)
])

pipe.fit(X_train, y_train)

y_pred = pipe.predict(X_test)

# %%
print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8132137673945881
# MAE 0.2046534054152755

# %%
np.exp(0.21)
# Out:
# np.float64(1.2336780599567432)

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(drop='first', sparse_output=False),[0,1,7,11,12])
],remainder='passthrough')

step2 = Ridge(alpha=10)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8171561845584201
# MAE 0.20599903654670698

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(drop='first', sparse_output=False),[0,1,7,11,12])
],remainder='passthrough')

step2 = KNeighborsRegressor(n_neighbors=3)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.806975307884076
# MAE 0.19104238048233457

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(drop='first', sparse_output=False),[0,1,7,11,12])
],remainder='passthrough')

step2 = DecisionTreeRegressor(max_depth=12)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8171225583915547
# MAE 0.20111073266530682

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(drop='first', sparse_output=False),[0,1,7,11,12])
],remainder='passthrough')

step2 = RandomForestRegressor(n_estimators=300,
                              random_state=3,
                              max_samples=0.5,
                              max_features=0.7,
                              max_depth=12)

pipe1 = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8929831304984153
# MAE 0.15751399060270957

# %%
train_score = pipe.score(X_train, y_train)
test_score = pipe.score(X_test, y_test)

print("Train R2:", train_score)
print("Test R2:", test_score)
# Out:
# Train R2: 0.9507623051745892
# Test R2: 0.8929831304984153

# %%
from sklearn.model_selection import cross_val_score

scores = cross_val_score(
    pipe,
    X_train,
    y_train,
    cv=5,
    scoring='r2'
)

print(scores)
print(scores.mean())
# Out:
# [0.85098381 0.88454018 0.87116888 0.88966019 0.88832519]
# 0.8769356488479716

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(drop='first', sparse_output=False),[0,1,7,11,12])
],remainder='passthrough')

step2 = XGBRegressor(n_estimators=45,max_depth=5,learning_rate=0.5)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8829296836317418
# MAE 0.15631331292861614

# %%
print(pipe1.named_steps['step2'])
# Out:
# RandomForestRegressor(max_depth=12, max_features=0.7, max_samples=0.5,
#                       n_estimators=300, random_state=3)

# %%
import pickle

pickle.dump(df, open('df.pkl', 'wb'))
pickle.dump(pipe1, open('pipe.pkl', 'wb'))
